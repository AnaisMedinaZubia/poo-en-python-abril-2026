# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaisMedinaZubia/poo-en-python-abril-2026/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Anais Medina NL = 36 fecha 21/Abril/2026
# #### Conceptos de OOPs (Object-Oriented Programming) Concepts in Python

# %% [markdown]
# lenguaje python, crear la clase ¨animal¨ con los atributos "nombre", "raza" crear el constructor animal, y las funciones ladrar(), correr(), crear los objetos pitbull, chihuahua, nivel principiante, no es interactivo, proporciona tu los datos

# %%
# 🏗️ Definición de la Clase Animal
class Animal:
    # 🐣 El Constructor: ¡Donde la magia comienza!
    def __init__(self, nombre, raza):
        self.nombre = nombre  # 🏷️ Nombre asignado
        self.raza = raza      # 📝 Tipo de raza

    # 🗣️ Método Ladrar: ¡Aumenta el volumen!
    def ladrar(self):
        print(f"🐕 {self.nombre} ({self.raza}) lanza un: ¡GUAU! 📢")

    # 🏎️ Método Correr: ¡Activa los motores!
    def correr(self):
        print(f"⚡ {self.nombre} está corriendo... 💨")

    # 🦷  Método Morder: ¡Cuidado con los dientes!
    def morder(self):
        print(f"🦴 {self.nombre} ha lanzado una mordida a la vecina")

# --- 🧪 Creación de los 3 Objetos (Instancias) ---

# 🦴 1. El Pitbull imponente
pitbull = Animal("Rambo 🥊", "Pitbull")

# 🌶️ 2. El Chihuahua valiente
chihuahua = Animal("Nacho 🌮", "Chihuahua")

# 🏘️ 3. El Perro Callejero (el alma del barrio)
callejero = Animal("Solovino 🦴", "Callejero")

# --- 🎬 ¡Acción en el parque! ---

print("🌳 --- ENCUENTRO EN EL PARQUE --- 🌳\n")

# 🐕 Acciones del Pitbull
pitbull.ladrar()
pitbull.correr()
pitbull.morder()

print("-" * 25)

# 🐕 Acciones del Chihuahua
chihuahua.ladrar()
chihuahua.correr()
chihuahua.morder()

print("-" * 25)

# 🐕 Acciones del Perro Callejero
callejero.ladrar()
callejero.correr()
callejero.morder()

print("\n🏆 ¡Todos los perros han terminado su rutina! ✨")
print("\n✨ ¡Fin del entrenamiento! ✨")
print("programa realizado por Anais Medina NL = 36")
# Out:
# 🌳 --- ENCUENTRO EN EL PARQUE --- 🌳
#
# 🐕 Rambo 🥊 (Pitbull) lanza un: ¡GUAU! 📢
# ⚡ Rambo 🥊 está corriendo... 💨
# 🦴 Rambo 🥊 ha lanzado una mordida a la vecina
# -------------------------
# 🐕 Nacho 🌮 (Chihuahua) lanza un: ¡GUAU! 📢
# ⚡ Nacho 🌮 está corriendo... 💨
# 🦴 Nacho 🌮 ha lanzado una mordida a la vecina
# -------------------------
# 🐕 Solovino 🦴 (Callejero) lanza un: ¡GUAU! 📢
# ⚡ Solovino 🦴 está corriendo... 💨
# 🦴 Solovino 🦴 ha lanzado una mordida a la vecina
#
# 🏆 ¡Todos los perros han terminado su rutina! ✨
#
# ✨ ¡Fin del entrenamiento! ✨
# programa realizado por Anais Medina NL = 36
